# %% [markdown]
# # TRL Ablations on OGBench
#
# This notebook runs the Transitive RL pipeline on the full battery of OGBench tasks like in the original paper, as well as running all of the other algorithms found in OGBench. It is organized as:
#
# 1. **Environment setup** — GPU runtime, installs, path config
# 2. **Project Root setup** — make sure that your files can be found correctly
# 3. **Sanity checks** — confirm JAX sees the GPU, imports resolve, TRL agent initializes
# 4. **Smoke test** — 500 steps with tiny batch; assert the pipeline doesn't crash and losses behave
# 5. **Full training run** — 1M steps, eval every 100K, checkpoint to Drive
#
# **Before you run anything:** Runtime → Change runtime type → **A100 GPU**. If you don't do this, everything will work, but training will be ~10× slower and you will be sad.
#
# The only thing that needs to be changed is the filepath in section 2 to match your own filepath.

# %% [markdown]
# ## 1. Environment setup

# %%
# Confirm we have a GPU before installing anything heavy.
# !nvidia-smi
# Out:
# Thu May  7 20:10:43 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0             42W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# Install repo requirements. Pinned to minimize Colab-specific breakage.
# JAX CUDA wheels need to match the driver; Colab's current default works with jax[cuda12].
# If JAX-CUDA detection fails later, the most common fix is reinstalling the matching wheel.
# !pip install -q \
    "jax[cuda12]>=0.4.26" \
    "flax>=0.8.4" \
    "distrax>=0.1.5" \
    ml_collections \
    matplotlib \
    moviepy \
    wandb \
    ogbench \
    imageio \
    tqdm
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.3/313.3 kB 31.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 9.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 170.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 17.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.0/101.0 kB 12.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 MB 48.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 157.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 145.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.5/243.5 kB 28.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 135.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ibis-framework 9.5.0 requires toolz<1,>=0.11, but you have toolz 1.1.0 which is incompatible.

# %%
# Mount Drive to persist dataset downloads and checkpoints across sessions.
# OGBench datasets are ~1GB and redownloading every session is painful.
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import os
os.environ['MUJOCO_GL'] = 'egl'
# Out:
# Mounted at /content/drive

# %%
# login to wandb
import wandb
wandb.login()
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: ljcho2005 (ljcho2005-princeton-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# ## 2. Upload & unpack the repo
#
# Add your own root filepath (aka everything before cos435-final-project/...) so that the notebook can find your files correctly
#
#  (NOTE: please comment out other people's filepaths when you run your own version)

# %%
# Veronica's filepath
root = '/content/drive/MyDrive'

# %%
# Luke's filepath
root = "/content/drive/MyDrive/Year 3/Sem 2/COS435"

# his other filepath
# root = "/content/drive/MyDrive/Classes"

# %%
# Tate's filepath
# root =

# %%
# Cheryl's filepath
# root =

# %%
# Maya's filepath
root = '/content/drive/MyDrive'

# %%
from pathlib import Path

PROJECT_ROOT = Path(root)

# %% [markdown]
# ## 3. Sanity checks
#
# Before burning GPU time, confirm the obvious things work: JAX sees the GPU

# %%
# Check: JAX sees the GPU
import jax
print('JAX version:', jax.__version__)
print('Devices:', jax.devices())
assert any('gpu' in str(d).lower() or 'cuda' in str(d).lower() for d in jax.devices()), (
    'No GPU found. Go to Runtime -> Change runtime type -> A100 GPU.'
)
# Out:
# JAX version: 0.7.2
# Devices: [CudaDevice(id=0)]

# %% [markdown]
# ## 4. Smoke test
# This is a short smoke test using the test_hyperparameters.py file (which uses 500 step runs using `pointmaze-medium-navigate-oraclerep-v0`). If something goes wrong, it probably should be fixed here before running EVERYTHING else. I have no idea how long this should take on A100s, but hopefully not long.

# %%
import os
import re
import hashlib
import subprocess
from datetime import datetime
from tqdm import tqdm

def run_experiments(commands, output_dir):
    output_dir = os.path.abspath(output_dir)

    run_id = datetime.now().strftime("%Y%m%d_%H%M%S")
    run_dir = os.path.join(output_dir, f"run_{run_id}")
    os.makedirs(run_dir, exist_ok=True)

    log_path = os.path.join(run_dir, "logs.txt")

    print(f"Starting run: {run_dir}")
    print("CWD before:", os.getcwd())

    os.chdir(PROJECT_ROOT / "cos435-final-project/test-runs/Transitive_Reinforcement_Learning_COS435/ogbench-master/impls")

    print("CWD after:", os.getcwd())
    pbar = tqdm(total=len(commands), desc="Running experiments", dynamic_ncols=True)
    for i, cmd in enumerate(commands):
        print(f"\n[{i+1}/{len(commands)}] Running: {cmd}")

        try:
            result = subprocess.run(
                cmd,
                shell=True,
                capture_output=True,
                text=True,
                env=os.environ.copy()
            )
        except Exception as e:
            print(f"EXCEPTION: {e}")
            continue

        with open(log_path, "a") as f:
            f.write("\n--- CMD ---\n")
            f.write(cmd + "\n")
            f.write("\n--- STDOUT ---\n")
            f.write(result.stdout or "")
            f.write("\n--- STDERR ---\n")
            f.write(result.stderr or "")
            f.write("\n--- RETURN CODE ---\n")
            f.write(str(result.returncode) + "\n")

        print("Return code:", result.returncode)

        if result.returncode != 0:
            print("FAILED — check logs.txt")
        pbar.update(1)

    pbar.close()

# %%
# parse the commands
hp_path = PROJECT_ROOT / "cos435-final-project/test-runs/Transitive_Reinforcement_Learning_COS435/ogbench-master/impls/test_hyperparams.sh"

with open(hp_path, "r") as f:
    hp_content = f.read()

test_commands = []
for line in hp_content.split("\n"):
    line = line.strip()

    if not line or line.startswith("#"):
        continue

    line = line.split("#")[0].strip()

    if line.startswith("python"):
        test_commands.append(line)

print(f"Found {len(test_commands)} commands in test_hyperparams.sh\n")
# Out:
# Found 1 commands in test_hyperparams.sh

# %%
# smoke test
run_experiments(test_commands, PROJECT_ROOT / "cos435-final-project/test-runs/checkpoints")
# Out:
# Starting run: /content/drive/MyDrive/cos435-final-project/test-runs/checkpoints/run_20260507_201127
# CWD before: /content
# CWD after: /content/drive/.shortcut-targets-by-id/1be05oOTeH9PxR215dunxExGyuFWIxWKI/cos435-final-project/test-runs/Transitive_Reinforcement_Learning_COS435/ogbench-master/impls
# Running experiments:   0%|          | 0/1 [00:00<?, ?it/s]
# [1/1] Running: python main.py --env_name=puzzle-3x3-play-oraclerep-v0 --agent=agents/trl.py --run_group=Test_3 --train_steps=500 --agent.actor_hidden_dims="(512, 512, 512)" --agent.value_hidden_dims="(512, 512, 512)" --agent.actor_geom_sample=False --agent.actor_p_trajgoal=1.0 --agent.actor_p_randomgoal=0.0 --agent.value_geom_sample=True --agent.discount=0.99 --agent.use_oracle_distillation=True --agent.expectile=0.7 --agent.distance_weight_lambda=0.7 --agent.policy_extraction=rejection
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_950/2335997890.py in <cell line: 0>()
#       1 # smoke test
# ----> 2 run_experiments(test_commands, PROJECT_ROOT / "cos435-final-project/test-runs/checkpoints")
#
# /tmp/ipykernel_950/2702929646.py in run_experiments(commands, output_dir)
#      26
#      27         try:
# ---> 28             result = subprocess.run(
#      29                 cmd,
#      30                 shell=True,
#
# /usr/lib/python3.12/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548     with Popen(*popenargs, **kwargs) as process:
#     549         try:
# --> 550             stdout, stderr = process.communicate(input, timeout=timeout)
#     551         except TimeoutExpired as exc:
#     552             process.kill()
#
# /usr/lib/python3.12/subprocess.py in communicate(self, input, timeout)
#    1207
#    1208             try:
# -> 1209                 stdout, stderr = self._communicate(input, endtime, timeout)
#    1210             except KeyboardInterrupt:
#    1211                 # https://bugs.python.org/issue25942
#
# /usr/lib/python3.12/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    2113                             'failed to raise TimeoutExpired.')
#    2114
# -> 2115                     ready = selector.select(timeout)
#    2116                     self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2117
#
# /usr/lib/python3.12/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:

# %% [markdown]
# ## 5. Full Runs
#
# This is where the main evaluation will happen. You dont need to modify anything.

# %%
# parse the commands for the original 3 long-horizon tasks
hp_path = PROJECT_ROOT / "cos435-final-project/test-runs/Transitive_Reinforcement_Learning_COS435/ogbench-master/impls/ablation_hyperparameters.sh"

with open(hp_path, "r") as f:
    hp_content = f.read()

commands = []
for line in hp_content.split("\n"):
    line = line.strip()

    if not line or line.startswith("#"):
        continue

    line = line.split("#")[0].strip()

    if line.startswith("python"):
        commands.append(line)

print(f"Found {len(commands)} commands in eval_hyperparams.sh\n")
for command in commands: print(command)
# Out:
# Found 1 commands in eval_hyperparams.sh
#
# ['python main.py --env_name=puzzle-4x4-play-v0 --agent=agents/trl.py --run_group=Ablation --train_steps=1000000 --agent.actor_hidden_dims="(512, 512, 512)" --agent.value_hidden_dims="(512, 512, 512)" --agent.actor_geom_sample=False --agent.actor_p_trajgoal=1.0 --agent.actor_p_randomgoal=0.0 --agent.value_p_trajgoal=0.0 --agent.value_p_randomgoal=1.0 --agent.value_geom_sample=True --agent.discount=0.99 --agent.use_oracle_distillation=False --agent.expectile=0.7 --agent.distance_weight_lambda=0.7 --agent.policy_extraction=ddpgbc --agent.alpha=2']

# %%
# if you are running the experiment for the first time
run_experiments(commands, PROJECT_ROOT / "cos435-final-project/test-runs/checkpoints")
# Out:
# Starting run: /content/drive/MyDrive/cos435-final-project/test-runs/checkpoints/run_20260507_201250
# CWD before: /content/drive/.shortcut-targets-by-id/1be05oOTeH9PxR215dunxExGyuFWIxWKI/cos435-final-project/test-runs/Transitive_Reinforcement_Learning_COS435/ogbench-master/impls
# CWD after: /content/drive/.shortcut-targets-by-id/1be05oOTeH9PxR215dunxExGyuFWIxWKI/cos435-final-project/test-runs/Transitive_Reinforcement_Learning_COS435/ogbench-master/impls
# Running experiments:   0%|          | 0/1 [00:00<?, ?it/s]
# [1/1] Running: python main.py --env_name=puzzle-4x4-play-v0 --agent=agents/trl.py --run_group=Ablation --train_steps=1000000 --agent.actor_hidden_dims="(512, 512, 512)" --agent.value_hidden_dims="(512, 512, 512)" --agent.actor_geom_sample=False --agent.actor_p_trajgoal=1.0 --agent.actor_p_randomgoal=0.0 --agent.value_p_trajgoal=0.0 --agent.value_p_randomgoal=1.0 --agent.value_geom_sample=True --agent.discount=0.99 --agent.use_oracle_distillation=False --agent.expectile=0.7 --agent.distance_weight_lambda=0.7 --agent.policy_extraction=ddpgbc --agent.alpha=2
# Running experiments: 100%|██████████| 1/1 [1:09:41<00:00, 4181.03s/it]
# Return code: 0
